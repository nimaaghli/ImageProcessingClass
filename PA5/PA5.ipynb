# %% [markdown]
# # Nima Aghli
# ## PA5
# ### DagSeg

# %%
# %matplotlib inline
#from pylab import *
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib.image as mpimg
from pylab import *
import pandas as pd
from scipy import misc
import scipy.fftpack as fftim
from scipy.misc.pilutil import Image
from PIL import Image
import cmath
from joblib import Parallel, delayed
import scipy.io as sio
from pims import ImageSequence
from skimage.segmentation import slic
from skimage.color import rgb2lab
from skimage import color
from skimage.segmentation import mark_boundaries
from skimage.util import img_as_float
from sklearn.preprocessing import Normalizer
from sklearn import metrics
from sklearn.cluster import KMeans, MiniBatchKMeans
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1-loading Frames And Masks Into Program

# %%
images = ImageSequence('images//birdfall2_000*.png')
masks = ImageSequence('masks//birdfall2_000*.png')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-32b94c3c1337> in <module>()
#       1 images = ImageSequence('images//birdfall2_000*.png')
# ----> 2 masks = ImageSequence('masks//birdfall2_000*.png')
#
# /Users/nimaaghli/miniconda3/lib/python3.5/site-packages/pims/image_sequence.py in __init__(self, path_spec, process_func, dtype, as_grey, plugin)
#      91         self._is_zipfile = False
#      92         self._zipfile = None
# ---> 93         self._get_files(path_spec)
#      94
#      95         tmp = self.imread(self._filepaths[0], **self.kwargs)
#
# /Users/nimaaghli/miniconda3/lib/python3.5/site-packages/pims/image_sequence.py in _get_files(self, path_spec)
#     161         # If there were no matches, this was probably a user typo.
#     162         if self._count == 0:
# --> 163             raise IOError("No files were found matching that path.")
#     164
#     165     def get_frame(self, j):
#
# OSError: No files were found matching that path.

# %%
framecount=29
fig = plt.figure(figsize=(15, 60))
fig.subplots_adjust(left=0.2, wspace=0.6)
fig.suptitle('20 Object Porposals For 20 Frames')
for k in range(0,framecount):
    img=images[k]       
    ax = fig.add_subplot(framecount, 5, k+1)
    ax.imshow(img)

# %%
fig = plt.figure(figsize=(10, 140))
fig.suptitle('Masks')
for k in range(0,framecount):
    img=masks[k]       
    ax = fig.add_subplot(framecount, 3, k+1)
    ax.imshow(img,cmap = plt.get_cmap('gray'), vmin = 0, vmax = 255)

# %%
fig = plt.figure(figsize=(10, 140))

fig.suptitle('Objects')
for k in range(0,framecount):
    img = cv2.bitwise_and(images[k],images[k],mask = masks[k])     
    ax = fig.add_subplot(framecount, 3, k+1)
    ax.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-79830f674973> in <module>()
#       2 fig.subplots_adjust(left=0.2, wspace=0.6)
#       3 fig.suptitle('Objects')
# ----> 4 for k in range(0,framecount):
#       5     img = cv2.bitwise_and(images[k],images[k],mask = masks[k])
#       6     ax = fig.add_subplot(framecount, 3, k+1)
#
# NameError: name 'framecount' is not defined

# %%
#images = ImageSequence('segments/DAGSeg//Image0*.png')
DAGSeg = ImageSequence('segments/DAGSeg//Image0*.png')
FastSeg = ImageSequence('segments/FastSeg//Image0*.png')
JOTSeg=ImageSequence('segments/JOTSeg//Image0*.png')

res = np.array([DAGSeg,FastSeg,JOTSeg])

# %%
fig = plt.figure()
fig.subplots_adjust(left=0.2, wspace=0.6)

ax1 = fig.add_subplot(221)
ax1.plot(2000*np.random.rand(10))
ax1.set_title('ylabels not aligned')
ax1.set_ylabel('misaligned 1', bbox=box)
ax1.set_ylim(0, 2000)
ax3 = fig.add_subplot(223)
ax3.set_ylabel('misaligned 2',bbox=box)
ax3.plot(np.random.rand(10))


labelx = -0.3  # axes coords

ax2 = fig.add_subplot(222)
ax2.set_title('ylabels aligned')
ax2.plot(2000*np.random.rand(10))
ax2.set_ylabel('aligned 1', bbox=box)
ax2.yaxis.set_label_coords(labelx, 0.5)
ax2.set_ylim(0, 2000)

ax4 = fig.add_subplot(224)
ax4.plot(np.random.rand(10))
ax4.set_ylabel('aligned 2', bbox=box)
ax4.yaxis.set_label_coords(labelx, 0.5)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-782e3e862d93> in <module>()
#       5 ax1.plot(2000*np.random.rand(10))
#       6 ax1.set_title('ylabels not aligned')
# ----> 7 ax1.set_ylabel('misaligned 1', bbox=box)
#       8 ax1.set_ylim(0, 2000)
#       9 ax3 = fig.add_subplot(223)
#
# /Users/nimaaghli/miniconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in set_ylabel(self, ylabel, fontdict, labelpad, **kwargs)
#     240         if labelpad is not None:
#     241             self.yaxis.labelpad = labelpad
# --> 242         return self.yaxis.set_label_text(ylabel, fontdict, **kwargs)
#     243
#     244     def _get_legend_handles(self, legend_handler_map=None):
#
# /Users/nimaaghli/miniconda3/lib/python3.5/site-packages/matplotlib/axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1476         if fontdict is not None:
#    1477             self.label.update(fontdict)
# -> 1478         self.label.update(kwargs)
#    1479         self.stale = True
#    1480         return self.label
#
# /Users/nimaaghli/miniconda3/lib/python3.5/site-packages/matplotlib/text.py in update(self, kwargs)
#     242         super(Text, self).update(kwargs)
#     243         if bbox:
# --> 244             self.set_bbox(bbox)  # depends on font properties
#     245
#     246     def __getstate__(self):
#
# /Users/nimaaghli/miniconda3/lib/python3.5/site-packages/matplotlib/text.py in set_bbox(self, rectprops)
#     490
#     491         if rectprops is not None:
# --> 492             props = rectprops.copy()
#     493             boxstyle = props.pop("boxstyle", None)
#     494             pad = props.pop("pad", None)
#
# AttributeError: 'function' object has no attribute 'copy'
